# %% [markdown]
# <center> <h1> Assignment - 18 </h1> </center>

# %% [markdown]
# ## Question - 1 , 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question - 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question - 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Define following -
# - Vector space
# - Norm
# - Linear independence
# - Rank of a matrix
# - cosine similarity
# - Orthogonality
# - Eigen value and eigen vector
