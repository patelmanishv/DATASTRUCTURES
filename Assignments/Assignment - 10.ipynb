# %% [markdown]
# ### 1. Define DBMS.
#
# ### 2. What is a primary and foreign key?
#
# ### 3. What are differences between file system and DB system?
#
# ### 4. What are CRUD operations in DBMS?
#
# ### 5. State the symbols used in ER diagram. (You can attach the images)
#
# # MCQs

# %% [markdown]
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2//EN">
# <FORM><B>Instructions:</B> Click the answer button to see the correct answer.
#    <OL><P><LI>Which of the following is not a characteristic of a relational database model?<OL TYPE="a">
# <LI>Tree like structure
# <LI>Records
# <LI>Complex logical relationship
# <LI>Table</OL>
# <BR><SELECT><OPTION>Answer<OPTION>a</SELECT><P><LI>Field is otherwise called as ......... of the record<OL TYPE="a">
# <LI>data type
# <LI>data item
# <LI>value
# <LI>variable</OL>
# <BR><SELECT><OPTION>Answer<OPTION>b</SELECT><P><LI>A table can have only one<OL TYPE="a">
# <LI>Alternate key
# <LI>Secondary key
# <LI>Primary key
# <LI>Unique key</OL>
# <BR><SELECT><OPTION>Answer<OPTION>c</SELECT><P><LI>A field can be called as ........... in relation context.<OL TYPE="a">
# <LI>attribute
# <LI>direct file
# <LI>tuple
# <LI>random file</OL>
# <BR><SELECT><OPTION>Answer<OPTION>a</SELECT><P><LI>In the relational modes, cardinality is termed as<OL TYPE="a">
# <LI>Number of tuples
# <LI>Number of constraints
# <LI>Number of tables
# <LI>Number of attributes</OL>
# <BR><SELECT><OPTION>Answer<OPTION>a</SELECT><P><LI>The ........ is used for creating and destroying table, indexes and other forms of structures.<OL TYPE="a">
# <LI>transaction control language
# <LI>data manipulation language
# <LI>data definition language
# <LI>data control language</OL>
# <BR><SELECT><OPTION>Answer<OPTION>c</SELECT><P><LI>The view of total database content is<OL TYPE="a">
# <LI>External view
# <LI>Physical view
# <LI>Conceptual view
# <LI>Internal view</OL>
# <BR><SELECT><OPTION>Answer<OPTION>c</SELECT><P><LI>The ............ refers to the way data is organized in and accessible from DBMS.<OL TYPE="a">
# <LI>data sharing
# <LI>data model
# <LI>database hierarchy
# <LI>data organization</OL>
# <BR><SELECT><OPTION>Answer<OPTION>b</SELECT><P><LI>Architecture of the database can be viewed as<OL TYPE="a">
# <LI>three levels
# <LI>four levels
# <LI>one level
# <LI>two levels</OL>
# <BR><SELECT><OPTION>Answer<OPTION>a</SELECT><P><LI> ........ introduced the relational database rules.<OL TYPE="a">
# <LI>EF Codd
# <LI>Dennies Rithchie
# <LI>James Gossling
# <LI>Atul kahate</OL>
# <BR><SELECT><OPTION>Answer<OPTION>a</SELECT><P><LI>In a relational model, relations are termed as<OL TYPE="a">
# <LI>Rows
# <LI>Tuples
# <LI>Tables
# <LI>Attributes</OL>
# <BR><SELECT><OPTION>Answer<OPTION>c</SELECT><P><LI>When the values in one or more attributes being used as a foreign key must exist in another set of<OL TYPE="a">
# <LI>referential integrity constraint
# <LI>normal form
# <LI>one or more attributes in another table, we have created a(n) ........
# <LI>insertion anomaly
# <LI>transitive dependency</OL>
# <BR><SELECT><OPTION>Answer<OPTION>c</SELECT><P><LI>In the architecture of a database system external level is the<OL TYPE="a">
# <LI>physical level
# <LI>view level
# <LI>conceptual level
# <LI>logical level</OL>
# <BR><SELECT><OPTION>Answer<OPTION>b</SELECT><P><LI>A functional dependency is a relationship between or among .......<OL TYPE="a">
# <LI>attributes
# <LI>tables
# <LI>relations
# <LI>rows</OL>
# <BR><SELECT><OPTION>Answer<OPTION>a</SELECT><P><LI>Related fields in a database are grouped to form a<OL TYPE="a">
# <LI>bank
# <LI>menu
# <LI>data file
# <LI>data record</OL>
# <BR><SELECT><OPTION>Answer<OPTION>d</SELECT><P><LI> .......... is, a table have more than one set of attributes that could be chosen as the key<OL TYPE="a">
# <LI>integrity key
# <LI>foreign key
# <LI>relationship
# <LI>candidate key</OL>
# <BR><SELECT><OPTION>Answer<OPTION>d</SELECT><P><LI>The database environment has all of the following components except.<OL TYPE="a">
# <LI>database administrator
# <LI>database
# <LI>separate files
# <LI>users</OL>
# <BR><SELECT><OPTION>Answer<OPTION>d</SELECT><P><LI>The operation of eliminating columns in a table done by ........ operation.<OL TYPE="a">
# <LI>Divide
# <LI>Union
# <LI>Restrict
# <LI>Project</OL>
# <BR><SELECT><OPTION>Answer<OPTION>d</SELECT><P><LI>The way a particular application views the data from the database that the application uses is a<OL TYPE="a">
# <LI>relational model
# <LI>module
# <LI>schema
# <LI>sub schema</OL>
# <BR><SELECT><OPTION>Answer<OPTION>d</SELECT><P><LI>....... is a condition specified on a database schema and restricts the data that can be stored in an instance of the database.<OL TYPE="a">
# <LI>Key Constraint
# <LI>integrity constraint
# <LI>Foreign key constraint
# <LI>Check Constraint</OL>
# <BR><SELECT><OPTION>Answer<OPTION>d</SELECT></OL></FORM>
# </BODY></HTML>
