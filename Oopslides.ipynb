# %% [markdown]
# <center><img src="images/types.jpeg" alt="drawing" width="900"/></center>

# %% [markdown]
# # Everything in Python is a Class / Object

# %%
x = 42
print(type(x))

y = 'hello'
print(type(y))

def z():
    pass
print(type(z))

import math
print(type(math))

print(type(type))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'function'>
# <class 'module'>
# <class 'type'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <center><img src="images/class.png" alt="drawing" width="750"/></center>

# %% [markdown]
# # Object
# > `An instance of a Class`

# %%
class Person:
    ...

x = Person()
y = Person()
x,y
# Out:
# (<__main__.Person at 0x189adcf58e0>, <__main__.Person at 0x189adfa5eb0>)

# %% [markdown]
# <center><img src="images/steve.jpg" alt="drawing" width="750"/></center>

# %% [markdown]
# <center><img src="images/obj.png" alt="drawing" width="750"/></center>

# %% [markdown]
# # Class
#
# >`A blueprint to make objects`

# %%
class Person:
    pass

# %% [markdown]
# <h1 style = "background-color:cyan; text-align:center"> PYTHON - VARIABLES </h1>

# %% [markdown]
# # Instance Variable
#
# >**A variable defined inside class which can only be accessed by current instance**

# %%
class Python:
    pass
x = Python()
y = Python()
x.m = 60
y.n = 70

# %% [markdown]
# # Class Variable
# >**A variable of class shared by all instances**

# %%
class Person:
    m = 'hello'
x = Person()
y = Person()

print(x.m)
print(y.m)
print(Person.m)
# Out:
# hello
# hello
# hello

# %%
class Account():
    rate = 5
    def some_method(self): 
          print(self.rate, Account.rate, id(self.rate), id(Account.rate))
          self.rate = 10
          print(self.rate, Account.rate, id(self.rate), id(Account.rate))
     
a1 = Account()
a2 = Account()
a1.some_method()
# Out:
# 5 5 2169912584624 2169912584624
# 10 5 2169912584784 2169912584624

# %% [markdown]
# # CLASS METHOD AND STATIC METHOD

# %%
class MyClass():

    a = 5
    def __init__(self, x):
          self.x = x
    def method1(self):
          print(self.x)
    @classmethod      
    def method2(cls):
          print(cls.a)
    @staticmethod
    def method3(m,n):
          return m+n         
f = MyClass(9)
f.method1()
f.method2()
f.method3(4,6)
# Out:
# 9
# 5
# 10

# %% [markdown]
# <center><img src="images/abstraction.png"" alt="drawing" width="750"/></center>

# %% [markdown]
# <center><img src="images/encap def.jpg" alt="drawing" width="700"/></center>

# %% [markdown]
# <center><img src="images/Encapsulation-illustration-with-capsule.png" alt="drawing" width="900"/></center>

# %% [markdown]
# <center><img src="images/encapsulation.jpeg" alt="drawing" width="900"/></center>

# %% [markdown]
# <center><img src="images/encaps.jpg"" alt="drawing" width="900"/></center>

# %%
# Data Hiding

class MyClass(object):             # Defining class 
    def __init__(self, x, y, z):   # Constructor method
        self.var1 = x              # public data member
        self._var2 = y             # protected data member
        self.__var3 = z            # private data member
        
obj = MyClass(3,4,5)
print(obj.var1)
print(obj._var2)

# print(obj.__var3)

print(obj._MyClass__var3)
# Out:
# 3
# 4
# 5

# %% [markdown]
# # POLYMORPHISM
#
# >**Polymorphism is the condition of occurrence in different forms**
#
#
# Python allows polymorphism in many different forms:
# 1. At the operator level (also known as operator overloading)
# 2. At the function level (also known as function overloading)
# 3. At the class level (also known as method overloading)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # TYPES OF POLYMORPHISM

# %% [markdown]
# <center><img src="images/types of polymorph.png" alt="drawing" width="500"/></center>

# %% [markdown]
# # OOPS Examples on Polymorphism

# %%
class Car:
    def start(self):
        print('Engine started')
    def move(self):
        print('Car is running')
    def stop(self):
        print('Brakes applied')

class Clock:
    def move(self):
        print('Tick Tick Tick')
    def stop(self):
        print('Clock needles stopped')

class Person:
    def move(self):
        print('Person walking')      
    def stop(self):
        print('Taking rest')
    def talk(self):
        print('Hello')

car = Car()
clock = Clock()
person = Person()

def do_something(x):
    x.move()
    x.stop()

do_something(car)
do_something(clock)
do_something(person)
# Out:
# Car is running
# Brakes applied
# Tick Tick Tick
# Clock needles stopped
# Person walking
# Taking rest

# %% [markdown]
# # Operator Overloading

# %%
i, j = 2000, 23
print(i + j)
s1 = "Computing"
s2 = "Lab"
print(s1 + " " + s2)
# Out:
# 2023
# Computing Lab

# %% [markdown]
# # Function Overloading

# %%
print(len("Python"))
print(len(["ver1", "ver2", "ver3"]))
print(len({"Creator": "Guido", "Nationality": "Dutch"}))
# Out:
# 6
# 3
# 2

# %% [markdown]
# # Method Overloading

# %%
class PythonProgrammer:
    def __init__(self, fullname):
        self.fullname = fullname
    def show(self):
        print("Creator of Python is: " + self.fullname)
        
class JavaProgrammer:
    def __init__(self, fullname):
        self.fullname = fullname
    def show(self):
        print("Creator of Java is: " + self.fullname)
        
PP = PythonProgrammer("Guido van Rossum")
PP.show()
JP = JavaProgrammer("James Gosling")
JP.show()
# Out:
# Creator of Python is: Guido van Rossum
# Creator of Java is: James Gosling

# %% [markdown]
# # METHOD OVERLOADING

# %% [markdown]
#    <center><img src="images/method.png" alt="drawing" width="500"/></center>

# %% [markdown]
# # OPERATOR OVERLOADING

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # METHOD OVERRIDING

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class MyClass(object):
    def set_val(self, val):
        self.value = val

    def get_val(self):
        print(self.value)


a = MyClass()
b = MyClass()

a.set_val(10)
b.set_val(1000)
a.value = 100  # <== Overriding `set_value` directly
# <== ie..  Breaking encapsulation

a.get_val()
b.get_val()
# Out:
# 100
# 1000

# %% [markdown]
# # PYTHON <span class="mark">ABSTRACTION</span>

# %% [markdown]
# <center><img src="images/venn.png" alt="drawing" width="600"/></center>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Abstract Class
# > **A class derived from ABC class which belongs to abc module, is known as `abstract class` in Python.**
# - ABC Class is known as Meta Class which means a class that defines the behavior of other classes. So we can say, Meta Class ABC defines that the class which is derived from it becomes an abstract class.
# - Abstract Class can have abstract method and concrete methods.
# - Abstract Class needs to be extended and its method implemented.
# - One cannot create objects of an abstract class!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Rules for abstract class
# - One can not create objects of an abstract class.
# - It is not necessary to declare all methods abstract in a abstract class.
# - Abstract Class can have abstract method and concrete methods.
# - If there is any abstract method in a class, that class must be abstract.
# - The abstract methods of an abstract class must be defined in its child class/subclass.
# - If you are inheriting any abstract class that have abstract method, you must either provide the implementation of the method or make this class abstract.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from abc import ABC, abstractmethod

class DefenceForce (ABC):
    def __init__(self):
        self.id = 101
    @abstractmethod
    def area(self):
        pass
    def gun(self):
        print("Gun = AK47")
        
class Army(DefenceForce):
    def area(self):
        print("Army Area = Land", self.id)
        
class AirForce(DefenceForce):
    def area(self):
        print("AirForce Area = Sky", self.id)
        
class Navy(DefenceForce):
    def area(self):
        print("Navy Area = Sea", self.id)

a = Army()
af = AirForce()
n = Navy()
a.gun()
a.area()
af.gun()
af.area()
n.gun()
n.area()
# Out:
# Gun = AK47
# Army Area = Land 101
# Gun = AK47
# AirForce Area = Sky 101
# Gun = AK47
# Navy Area = Sea 101

# %% [markdown]
# # INHERITANCE
#
# > **INFORMATION SHARING**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Inheritance - KEY CONCEPTS
# - A class can inherit from another class.
# - Inheritance improves code reuse.
# - Constructor, attributes, methods get inherited to the child class.
# - The parent has no access to the child class.
# - Private properties of parent class are not accessible directly in child class.
# - Child class can override the attributes or methods. This is called method overriding.
# - super() is an inbuilt function which is used to invoke the parent class methods and constructor.

# %% [markdown]
# # TYPES OF INHERITANCE

# %% [markdown]
# <center><img src="images/INHERITYPES.png" alt="drawing" width="700"/></center>

# %% [markdown]
# # Single Inheritance

# %%
class Person: 
    def __init__(self, fullname):
        self.fullname = fullname
    def show(self):
        print(self.fullname + " is a Python teacher")

class Professor(Person):
    pass
per = Person("Manish Patel")
per.show()
pro = Professor("Guido Rossum")
pro.show()
# Out:
# Manish Patel is a Python teacher
# Guido Rossum is a Python teacher

# %% [markdown]
# # Multi Level Inheritance

# %%
class Human:
    def __init__(self, fullname):
        self.fullname = fullname
    def show(self):
        print(self.fullname + " is a python teacher")
        
class Person(Human):
    pass

class Professor(Person):
    pass

p = Professor("Manish Patel")
p.show()
# Out:
# Manish Patel is a python teacher

# %% [markdown]
# # Multiple Inheritance

# %%
class Person:
    def __init__(self, fullname):
        self.fullname = fullname
    def show(self):
        print(self.fullname + " is a person.")

class Teacher():
    def credit(self):
        print("He teaches python.")
        
class PythonProgrammer(Person, Teacher):
    pass


PP = PythonProgrammer("Manish Patel")
PP.show()
PP.credit()
# Out:
# Manish Patel is a person.
# He teaches python.

# %% [markdown]
# # Hierarchical Inheritance

# %%
class Human:
    def __init__(self, fullname):
        self.fullname = fullname
    def show(self):
            print(self.fullname + " is a professor")

class PythonProgrammer(Human):
    pass

class JavaProgrammer(Human):
    pass

PP = PythonProgrammer("Manish Patel")
PP.show()

JP = JavaProgrammer("James Gosling")
JP.show()
# Out:
# Manish Patel is a professor
# James Gosling is a professor

# %% [markdown]
# # Constructor Overriding

# %%
class Father: # Parent Class
    def __init__(self):
        self.money = 1000
        print("Father Class Constructor")
    def show(self):
            print("Father Class Instance Method")
class Son(Father): # Child Class
    def __init__(self):
        self.money = 5000
        self.car = 'BMW'
        print("Son Class Constructor")
    def disp(self):
        print("Son Class Instance Method")
s = Son()
print(s.money)
print(s.car)
s.disp()
s.show()
# Out:
# Son Class Constructor
# 5000
# BMW
# Son Class Instance Method
# Father Class Instance Method

# %% [markdown]
# # `Super()` Keyword
# - If we write constructor in the both classes, parent class and child class then the parent class constructor is not available to the child class.
# - In this case only child class constructor is accessible which means child class constructor is replacing parent class constructor.
# - `super()` method is used to call parent class constructor or methods from the child class.

# %%
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera
    def buy(self):
            print ("Buying a phone")
            
class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        super().buy()                 # syntax to call parent's buy method
s=SmartPhone(20000, "Apple", 13)
s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone
# Buying a phone

# %%
# Constructor with Super Method
class Father: # Parent Class
    def __init__(self):
        print("Father Class Constructor")
    def show(self):
        print("Father Class Instance Method")
        
class Son(Father): # Child Class
    def __init__(self):
        super().__init__() # Calling Parent Class Constructor
        print("Son Class Constructor")
    def disp(self):
        print("Son Class Instance Method")
        
s = Son()
s.disp()
s.show()
# Out:
# Father Class Constructor
# Son Class Constructor
# Son Class Instance Method
# Father Class Instance Method

# %% [markdown]
# # Method Resolution Order (MRO)
# - In multiple inheritance scenarios, any specific attribute or method will initially be searched in the current class. If not found in the current class, then next search continues into parent classes in depth-first left to right fashion. Searching in this order is called `Method Resolution Order(MRO).`

# %% [markdown]
# # C3 LINEARIZATION ALGORITHM

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # EXAMPLE

# %%
class F(object):
    pass
class E(object):
    pass
class D(object):
    pass
class C(D, F):
    pass
class B(D, E):
    def method1:
class A(B, C):
    def method1:

# %%
m = A()
m.method1()
A.__mro__
# Out:
# (__main__.A,
#  __main__.B,
#  __main__.C,
#  __main__.D,
#  __main__.E,
#  __main__.F,
#  object)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # MRO of `B`
#
# 1. L[B]=B+merge(L[D],L[E],DE)
# 1. L[B]=B+merge(DO,EO,DE)
# 1. L[B]=B+D+merge(O,EO,E)
# 1. L[B]=B+D+E+merge(O,O)
# 1. L[B]=B+D+E+O
# 1. L[B]=BDEO

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # MRO of `A`
#
# L[A]=A+merge(L[B],L[C],BC)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # MRO Example problem for practice
#
# ```python
#
# class A:
#     def m1(self):
#         print("m1 from A")
#
# class B(A):
#     def m1(self):
#         print("m1 from B")
#
# class C(A):
#     def m1(self):
#         print("m1 from C")
#
# class D(B, C):
#     def m1(self):
#         print("m1 from D")
# ```
